# %%
import pandas
pandas.set_option('display.max_columns', 20)
pandas.set_option('display.width', 350)
query=pandas.read_csv("query_one.csv")
print(query)
# Out:
#       user_id                       page  unix_timestamp
# 0        6684                  home_page      1451640067
# 1        8098                  home_page      1451647141
# 2        9440                  home_page      1451653638
# 3        1003                  home_page      1451611211
# 4        4272               product_page      1451628024
# ...       ...                        ...             ...
# 9995     3459                  home_page      1451623940
# 9996     8732                  home_page      1451650208
# 9997     7496  payment_confirmation_page      1451644240
# 9998     9201                  home_page      1451652509
# 9999     8568                  home_page      1451649405
#
# [10000 rows x 3 columns]

# %%
id_list=sorted(query['user_id'].unique())

# %%
for id in id_list:
    ttemp=query[query['user_id']==id]
    t1=ttemp.sort_values('unix_timestamp', ascending=False)
    #print(t1)
    if len(t1)<2:
        print('NULL')
    else:
        print(t1['unix_timestamp'].iloc[0]-t1['unix_timestamp'].iloc[1])
# Out:
# NULL
# 2
# 4
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# 7
# NULL
# NULL
# NULL
# NULL
# 6
# NULL
# NULL
# 1
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# 8
# 1
# NULL
# NULL
# 1
# NULL
# 1
# NULL
# NULL
# 5
# 1
# NULL
# 2
# NULL
# NULL
# NULL
# 2
# 3
# 10
# NULL
# 5
# 2
# NULL
# NULL
# NULL
# 5
# NULL
# NULL
# 8
# NULL
# NULL
# 1
# 4
# NULL
# 3
# NULL
# NULL
# NULL
# 4
# NULL
# NULL
# 2
# 1
# NULL
# NULL
# NULL
# 1
# NULL
# NULL
# NULL
# 2
# 1
# NULL
# NULL
# 1
# NULL
# NULL
# 11
# 13
# 2
# NULL
# NULL
# NULL
# NULL
# 24
# NULL
# 2
# NULL
# NULL
# NULL
# NULL
# NULL
# 3
# NULL
# 11
# NULL
# 17
# 18
# NULL
# NULL
# NULL
# 2
# NULL
# NULL
# NULL
# 1
# NULL
# NULL
# 2
# NULL
# NULL
# NULL
# NULL
# NULL
# 9
# NULL
# 7
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# 5
# 3
# NULL
# NULL
# 1
# NULL
# NULL
# 2
# NULL
# 1
# 6
# 3
# 4
# NULL
# NULL
# 1
# NULL
# 1
# NULL
# 1
# NULL
# 1
# NULL
# NULL
# 3
# NULL
# 10
# 2
# 4
# 1
# 1
# NULL
# NULL
# 2
# 7
# ...
